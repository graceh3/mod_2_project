# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
import statsmodels.stats.api as sms
import statsmodels.formula.api as smf
import scipy.stats as stats
import seaborn as sns
from statsmodels.formula.api import ols 

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from itertools import combinations

# %%
df = pd.read_csv('df_master91.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  zipcode  median_income  population           county  \
# 0           0    10001     71244.6100       17678  New York County
# 1           1    10002     30843.9574       70878  New York County
# 2           2    10003     89998.5339       53609  New York County
# 3           3    10004    110183.6857        1271  New York County
# 4           4    10005    115133.2855        1517  New York County
#
#    median_rent  restaurant_count  recycling_bin_count  num_subway_entrances  \
# 0       3400.0             488.0                  1.0                  51.0
# 1       3050.0             509.0                 10.0                  19.0
# 2       3750.0             682.0                  7.0                  28.0
# 3       3876.0             145.0                  3.0                   6.0
# 4       3910.0              72.0                  3.0                   0.0
#
#   subway_bracket
# 0        (6, 72]
# 1        (6, 72]
# 2        (6, 72]
# 3         (0, 6]
# 4              0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'zipcode', 'median_income', 'population', 'county',
#        'median_rent', 'restaurant_count', 'recycling_bin_count',
#        'num_subway_entrances', 'subway_bracket'],
#       dtype='object')

# %%
#df[['median_income', 'population', 'county', 'median_rent',
#       'restaurant_count', 'recycling_bin_count', 'num_subway_entrances',
#       'subway_bracket']].hist(figsize  = [18, 18])

# %%
# fig, axs = plt.subplots(1, 2, sharey=False, figsize=(18, 6))
# for idx, dollars in enumerate(['median_rent_07_to_11', 'median_rent_12_to_16']):
#     df_combined.plot(kind='scatter', x=dollars, y='median_income_07_to_11', ax=axs[idx], label=dollars)
# plt.legend()
# plt.show()

# %%
df[df.county == 'Richmond County']
# Out:
#     Unnamed: 0  zipcode  median_income  population           county  \
# 41          41    10305     58937.6580       37014  Richmond County
# 42          42    10306     75212.0632       54812  Richmond County
# 43          43    10312     84524.3656       55963  Richmond County
# 44          44    10314     78413.7436       85260  Richmond County
#
#     median_rent  restaurant_count  recycling_bin_count  num_subway_entrances  \
# 41       2200.0              93.0                  2.0                   4.0
# 42       2300.0             113.0                  7.0                  10.0
# 43       2350.0              78.0                  2.0                   6.0
# 44       2300.0             189.0                  4.0                   0.0
#
#    subway_bracket
# 41         (0, 6]
# 42        (6, 72]
# 43         (0, 6]
# 44              0

# %%
df_pairplot = df[['median_income','population', 'median_rent', 'restaurant_count', 'recycling_bin_count', 'num_subway_entrances']]

# %%
df_pairplot
# Out:
#     median_income  population  median_rent  restaurant_count  \
# 0      71244.6100       17678       3400.0             488.0
# 1      30843.9574       70878       3050.0             509.0
# 2      89998.5339       53609       3750.0             682.0
# 3     110183.6857        1271       3876.0             145.0
# 4     115133.2855        1517       3910.0              72.0
# 5     111220.0000         972       3700.0              45.0
# 6     145458.7823        3520       6325.0             141.0
# 7      56615.2777       56975       3350.0             311.0
# 8      93702.0061       27322       3500.0             259.0
# 9      92359.4888       45899       3695.0             455.0
# 10     81316.7066       26464       3350.0             429.0
# 11     69836.0955       24723       5195.0             497.0
# 12     98449.9155       32867       3700.0             424.0
# 13     96760.4462       49904       3400.0             441.0
# 14    102523.5025       16231       3000.0             358.0
# 15     84799.0772        4255       3495.0             382.0
# 16     84786.4665       39048       3595.0             695.0
# 17    113800.3846       44173       3295.0             150.0
# 18     93106.6559       26460       3252.0             463.0
# 19    108285.5918       59002       3697.0             197.0
# 20    110998.9883       61485       3300.0             196.0
# 21     65001.2415       96117       3400.0             232.0
# 22     31541.8106       25925       2600.0              88.0
# 23     38550.3989       57049       2600.0             169.0
# 24    105456.4514       40914       2895.0             198.0
# 25     32876.5220       76271       3375.0             208.0
# 26     28525.1218       26058       1800.0              37.0
# 27     31526.0287       59450       2000.0             118.0
# 28     29535.9721       54744       1900.0             114.0
# 29     36462.7783       59049       1950.0             120.0
# ..            ...         ...          ...               ...
# 61     81331.0535       59307       2700.0             339.0
# 62     37290.3205       55021       2300.0             185.0
# 63     72610.5963       35641       3100.0             284.0
# 64     48010.6089       75418       2100.0             151.0
# 65     34005.1582       75020       2400.0             142.0
# 66     54366.9033       40003       2900.0             227.0
# 67     39420.9802       74659       1950.0             174.0
# 68     38763.3706      106461       1712.5             211.0
# 69     55200.2725       40169       2200.0              56.0
# 70     49910.6032       80407       2200.0             129.0
# 71     47496.1618       88449       1700.0             111.0
# 72     73074.9877       33174       3200.0             166.0
# 73     67952.9473       81033       2200.0             149.0
# 74     44729.6710       79197       2000.0             173.0
# 75     61468.5107       49085       2900.0             250.0
# 76     50019.4132       54286       2300.0             464.0
# 77     38623.9557       74434       2000.0             222.0
# 78     67807.8323       20443       2275.0              58.0
# 79     74096.6311       39650       2500.0              77.0
# 80     66312.1712       37044       2200.0             156.0
# 81     72853.7515       18363       2650.0              22.0
# 82     70983.2093       28648       2200.0             133.0
# 83     61097.3200       37503       2500.0              54.0
# 84     53564.6755       39791       1900.0              53.0
# 85     49707.9331       39224       1850.0              95.0
# 86     69446.0737       70142       2022.5             209.0
# 87     47469.8714       95262       2200.0             292.0
# 88     50291.2065       54915       2400.0             186.0
# 89     44721.7965       47317       1950.0             111.0
# 90     54873.7130       11120       1600.0              36.0
#
#     recycling_bin_count  num_subway_entrances
# 0                   1.0                  51.0
# 1                  10.0                  19.0
# 2                   7.0                  28.0
# 3                   3.0                   6.0
# 4                   3.0                   0.0
# 5                   2.0                  30.0
# 6                   9.0                  26.0
# 7                  13.0                   4.0
# 8                   0.0                   0.0
# 9                   1.0                  72.0
# 10                  8.0                  34.0
# 11                 10.0                  14.0
# 12                 14.0                   0.0
# 13                  2.0                   0.0
# 14                  2.0                   5.0
# 15                  4.0                  26.0
# 16                  2.0                  16.0
# 17                  0.0                  12.0
# 18                  2.0                   3.0
# 19                  8.0                  16.0
# 20                  0.0                   0.0
# 21                  1.0                   9.0
# 22                  6.0                  16.0
# 23                  2.0                  10.0
# 24                  0.0                  16.0
# 25                  3.0                  10.0
# 26                  4.0                  17.0
# 27                  1.0                   6.0
# 28                  3.0                  23.0
# 29                  0.0                   0.0
# ..                  ...                   ...
# 61                  5.0                  23.0
# 62                  0.0                  12.0
# 63                  5.0                  41.0
# 64                  0.0                  16.0
# 65                  0.0                   4.0
# 66                  9.0                  11.0
# 67                  1.0                  26.0
# 68                  1.0                  14.0
# 69                  0.0                   4.0
# 70                  2.0                   0.0
# 71                  1.0                  20.0
# 72                  5.0                  12.0
# 73                  0.0                   0.0
# 74                  3.0                  16.0
# 75                  6.0                  29.0
# 76                  0.0                   0.0
# 77                  4.0                  10.0
# 78                  0.0                   0.0
# 79                  0.0                   0.0
# 80                  2.0                   0.0
# 81                  2.0                   0.0
# 82                  1.0                   0.0
# 83                  6.0                   0.0
# 84                  6.0                   0.0
# 85                  1.0                   7.0
# 86                  3.0                  11.0
# 87                  1.0                   2.0
# 88                  1.0                  22.0
# 89                  1.0                  24.0
# 90                  0.0                   1.0
#
# [91 rows x 6 columns]

# %%
sns.pairplot(df, vars = ['median_income','population', 'median_rent', 'restaurant_count', 'recycling_bin_count', 'num_subway_entrances'],
             diag_kind = 'kde')
# Out:
# /Users/gracejeong/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.savefig('pairplot_all')

# %%
plt.figure()
sns.pairplot(df, vars = ['median_income','population', 'median_rent', 'restaurant_count', 'recycling_bin_count', 'num_subway_entrances'], hue = 'county')
plt.savefig('pairplot_bycounty.png')

# %%
df_pairplot_ny = df[df.county == 'New York County'][['median_income','population', 'median_rent', 'restaurant_count', 'recycling_bin_count', 'num_subway_entrances']]
df_pairplot_kings = df[df.county == 'Kings County'][['median_income','population', 'median_rent', 'restaurant_count', 'recycling_bin_count', 'num_subway_entrances']]
df_pairplot_queens = df[df.county == 'Queens County'][['median_income','population', 'median_rent', 'restaurant_count', 'recycling_bin_count', 'num_subway_entrances']]
df_pairplot_richmond = df[df.county == 'Richmond County'][['median_income','population', 'median_rent', 'restaurant_count', 'recycling_bin_count', 'num_subway_entrances']]
df_pairplot_bronx = df[df.county == 'Bronx County'][['median_income','population', 'median_rent', 'restaurant_count', 'recycling_bin_count', 'num_subway_entrances']]

# %%
sns.pairplot(df_pairplot_ny, kind='reg')

# %%
# sns.pairplot(df_pairplot_kings, kind='reg')

# %%
# sns.heatmap(df_pairplot.corr(),vmin=-1, vmax=1, annot = True)
# plt.title('All Boroughs')
# plt.savefig('corr_heatmap_all')

# %%
# df_pairplot.corr()

# %%
# sns.heatmap(df_pairplot_ny.corr(),vmin=-1, vmax=1, annot = True)
# plt.title('Manhattan')
# plt.savefig('corr_heatmap_ny')

# %%
# sns.heatmap(df_pairplot_kings.corr(),vmin=-1, vmax=1, annot = True)
# plt.title('Brooklyn')
# plt.savefig('corr_heatmap_brooklyn')

# %%
# sns.heatmap(df_pairplot_queens.corr(),vmin=-1, vmax=1, annot = True)
# plt.title('Queens')
# plt.savefig('corr_heatmap_queens')

# %%
# sns.heatmap(df_pairplot_richmond.corr(),vmin=-1, vmax=1, annot = True)
# plt.title('Staten Island')
# plt.savefig('corr_heatmap_staten')

# %%
# sns.heatmap(df_pairplot_bronx.corr(),vmin=-1, vmax=1, annot = True)
# plt.title('Bronx')
# plt.savefig('corr_heatmap_bronx')

# %% [markdown]
# ## ANOVA

# %%
formula = 'median_income ~ median_rent + C(county) + recycling_bin_count + C(subway_bracket) +restaurant_count'
lm = ols(formula, df).fit()
table = sm.stats.anova_lm(lm, typ=2)
print(table)
# Out:
#                            sum_sq    df          F        PR(>F)
# C(county)            1.936111e+09   4.0   1.361118  2.547475e-01
# C(subway_bracket)    1.986685e+09   2.0   2.793343  6.712323e-02
# median_rent          2.220887e+10   1.0  62.452796  1.167664e-11
# recycling_bin_count  1.622631e+09   1.0   4.562944  3.568985e-02
# restaurant_count     3.746474e+08   1.0   1.053533  3.077504e-01
# Residual             2.880445e+10  81.0        NaN           NaN

# %% [markdown]
# ## Feature Scaling and Normalization

# %%
df.isna().sum()
# Out:
# Unnamed: 0              0
# zipcode                 0
# median_income           0
# population              0
# county                  0
# median_rent             0
# restaurant_count        0
# recycling_bin_count     0
# num_subway_entrances    0
# subway_bracket          0
# dtype: int64

# %%
df[["median_income", "recycling_bin_count", "median_rent", "restaurant_count"]].hist(figsize  = [6, 6]);

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20,10))
sns.boxplot(x=df["median_income"], orient = 'v', ax = axes[0,0], palette = 'deep')
sns.boxplot(x=df["median_rent"], orient = 'v',ax = axes[0,1], palette = 'deep')
sns.boxplot(x=df["recycling_bin_count"], orient = 'v', ax = axes[1,0], palette = 'deep')
sns.boxplot(x=df["restaurant_count"], orient = 'v', ax = axes[1,1], palette = 'deep')

# %%
sns.boxplot(x=df["median_rent"], orient = 'v')

# %%
sns.boxplot(x=df["recycling_bin_count"], orient = 'v')

# %%
sns.boxplot(x=df["restaurant_count"], orient = 'v')

# %%
df["logincome"] = np.log(df["median_income"])
df["logrent"] = np.log(df["median_rent"])
df["logrestaurant"] = np.log(df["restaurant_count"])
df["recycling_bin_count"] = np.log(df["recycling_bin_count"]+1)
df[["logincome", "logrent", "logrestaurant", "recycling_bin_count"]].hist(figsize  = [6, 6]);

# %%
# compare original county categorical column w/ dummy column
mo =  smf.ols(formula='logincome ~ C(county) + logrent',
                 data=df).fit()
mo.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              logincome   R-squared:                       0.488
# Model:                            OLS   Adj. R-squared:                  0.458
# Method:                 Least Squares   F-statistic:                     16.19
# Date:                Wed, 13 Mar 2019   Prob (F-statistic):           3.44e-11
# Time:                        17:34:51   Log-Likelihood:                -20.778
# No. Observations:                  91   AIC:                             53.56
# Df Residuals:                      85   BIC:                             68.62
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        2.9074      1.036      2.806      0.006       0.847       4.968
# C(county)[T.Kings County]       -0.1957      0.145     -1.350      0.181      -0.484       0.093
# C(county)[T.New York County]    -0.1841      0.153     -1.202      0.233      -0.489       0.120
# C(county)[T.Queens County]      -0.0275      0.146     -0.189      0.851      -0.317       0.262
# C(county)[T.Richmond County]     0.2001      0.202      0.991      0.324      -0.201       0.601
# logrent                          1.0471      0.139      7.553      0.000       0.771       1.323
# ==============================================================================
# Omnibus:                        5.177   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.075   Jarque-Bera (JB):                4.912
# Skew:                          -0.569   Prob(JB):                       0.0858
# Kurtosis:                       3.033   Cond. No.                         252.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model = smf.ols(formula='logincome ~ logrent',
                 data=df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              logincome   R-squared:                       0.439
# Model:                            OLS   Adj. R-squared:                  0.433
# Method:                 Least Squares   F-statistic:                     69.65
# Date:                Wed, 13 Mar 2019   Prob (F-statistic):           8.46e-13
# Time:                        17:34:51   Log-Likelihood:                -24.919
# No. Observations:                  91   AIC:                             53.84
# Df Residuals:                      89   BIC:                             58.86
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.7931      0.863      4.394      0.000       2.078       5.508
# logrent        0.9180      0.110      8.346      0.000       0.699       1.137
# ==============================================================================
# Omnibus:                        6.569   Durbin-Watson:                   1.677
# Prob(Omnibus):                  0.037   Jarque-Bera (JB):                6.724
# Skew:                          -0.662   Prob(JB):                       0.0347
# Kurtosis:                       2.866   Cond. No.                         204.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model2 = smf.ols(formula='logincome ~ logrent + recycling_bin_count',
                 data=df).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              logincome   R-squared:                       0.471
# Model:                            OLS   Adj. R-squared:                  0.459
# Method:                 Least Squares   F-statistic:                     39.11
# Date:                Wed, 13 Mar 2019   Prob (F-statistic):           7.04e-13
# Time:                        17:34:51   Log-Likelihood:                -22.285
# No. Observations:                  91   AIC:                             50.57
# Df Residuals:                      88   BIC:                             58.10
# Df Model:                           2
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               3.5251      0.851      4.140      0.000       1.833       5.217
# logrent                 0.9656      0.109      8.822      0.000       0.748       1.183
# recycling_bin_count    -0.0943      0.041     -2.290      0.024      -0.176      -0.012
# ==============================================================================
# Omnibus:                        7.179   Durbin-Watson:                   1.646
# Prob(Omnibus):                  0.028   Jarque-Bera (JB):                7.519
# Skew:                          -0.685   Prob(JB):                       0.0233
# Kurtosis:                       2.674   Cond. No.                         208.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model3 = smf.ols(formula='logincome ~ logrent + recycling_bin_count + C(subway_bracket)',
                 data=df).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              logincome   R-squared:                       0.509
# Model:                            OLS   Adj. R-squared:                  0.486
# Method:                 Least Squares   F-statistic:                     22.25
# Date:                Wed, 13 Mar 2019   Prob (F-statistic):           1.23e-12
# Time:                        17:34:52   Log-Likelihood:                -18.894
# No. Observations:                  91   AIC:                             47.79
# Df Residuals:                      86   BIC:                             60.34
# Df Model:                           4
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        3.5614      0.838      4.251      0.000       1.896       5.227
# C(subway_bracket)[T.(6, 72]]    -0.0575      0.091     -0.631      0.530      -0.239       0.124
# C(subway_bracket)[T.0]           0.1442      0.101      1.427      0.157      -0.057       0.345
# logrent                          0.9564      0.107      8.947      0.000       0.744       1.169
# recycling_bin_count             -0.0670      0.042     -1.604      0.112      -0.150       0.016
# ==============================================================================
# Omnibus:                        5.652   Durbin-Watson:                   1.760
# Prob(Omnibus):                  0.059   Jarque-Bera (JB):                5.762
# Skew:                          -0.592   Prob(JB):                       0.0561
# Kurtosis:                       2.656   Cond. No.                         211.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model4 = smf.ols(formula='logincome ~ logrent + recycling_bin_count + C(subway_bracket) + restaurant_count',
                 data=df).fit()
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              logincome   R-squared:                       0.513
# Model:                            OLS   Adj. R-squared:                  0.485
# Method:                 Least Squares   F-statistic:                     17.93
# Date:                Wed, 13 Mar 2019   Prob (F-statistic):           4.25e-12
# Time:                        17:34:52   Log-Likelihood:                -18.460
# No. Observations:                  91   AIC:                             48.92
# Df Residuals:                      85   BIC:                             63.99
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        3.2165      0.922      3.490      0.001       1.384       5.049
# C(subway_bracket)[T.(6, 72]]    -0.0446      0.092     -0.483      0.630      -0.228       0.139
# C(subway_bracket)[T.0]           0.1488      0.101      1.469      0.145      -0.053       0.350
# logrent                          1.0044      0.120      8.404      0.000       0.767       1.242
# recycling_bin_count             -0.0633      0.042     -1.506      0.136      -0.147       0.020
# restaurant_count                -0.0002      0.000     -0.902      0.370      -0.001       0.000
# ==============================================================================
# Omnibus:                        6.125   Durbin-Watson:                   1.770
# Prob(Omnibus):                  0.047   Jarque-Bera (JB):                6.313
# Skew:                          -0.629   Prob(JB):                       0.0426
# Kurtosis:                       2.713   Cond. No.                     7.29e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.29e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model5 = smf.ols(formula='logincome ~ logrent + recycling_bin_count + C(subway_bracket) + restaurant_count*population',
                 data=df).fit()
model5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              logincome   R-squared:                       0.527
# Model:                            OLS   Adj. R-squared:                  0.487
# Method:                 Least Squares   F-statistic:                     13.19
# Date:                Wed, 13 Mar 2019   Prob (F-statistic):           2.63e-11
# Time:                        17:34:52   Log-Likelihood:                -17.201
# No. Observations:                  91   AIC:                             50.40
# Df Residuals:                      83   BIC:                             70.49
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        4.1131      1.131      3.637      0.000       1.864       6.363
# C(subway_bracket)[T.(6, 72]]    -0.0272      0.093     -0.292      0.771      -0.212       0.158
# C(subway_bracket)[T.0]           0.1514      0.101      1.496      0.139      -0.050       0.353
# logrent                          0.8982      0.141      6.374      0.000       0.618       1.179
# recycling_bin_count             -0.0649      0.042     -1.531      0.129      -0.149       0.019
# restaurant_count             -5.121e-05      0.000     -0.113      0.911      -0.001       0.001
# population                   -2.104e-06   2.65e-06     -0.794      0.429   -7.37e-06    3.16e-06
# restaurant_count:population   -1.13e-09   1.09e-08     -0.103      0.918   -2.29e-08    2.06e-08
# ==============================================================================
# Omnibus:                        5.760   Durbin-Watson:                   1.686
# Prob(Omnibus):                  0.056   Jarque-Bera (JB):                5.901
# Skew:                          -0.606   Prob(JB):                       0.0523
# Kurtosis:                       2.701   Cond. No.                     4.46e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.46e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model6 = smf.ols(formula='logincome ~ logrent + recycling_bin_count + C(subway_bracket) + restaurant_count*population + C(county)',
                 data=df).fit()
model6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              logincome   R-squared:                       0.581
# Model:                            OLS   Adj. R-squared:                  0.523
# Method:                 Least Squares   F-statistic:                     9.972
# Date:                Wed, 13 Mar 2019   Prob (F-statistic):           4.32e-11
# Time:                        17:34:52   Log-Likelihood:                -11.604
# No. Observations:                  91   AIC:                             47.21
# Df Residuals:                      79   BIC:                             77.34
# Df Model:                          11
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        3.3355      1.226      2.721      0.008       0.895       5.776
# C(subway_bracket)[T.(6, 72]]     0.0384      0.093      0.415      0.679      -0.146       0.223
# C(subway_bracket)[T.0]           0.1795      0.100      1.793      0.077      -0.020       0.379
# C(county)[T.Kings County]       -0.2049      0.144     -1.418      0.160      -0.492       0.083
# C(county)[T.New York County]    -0.2902      0.151     -1.927      0.058      -0.590       0.010
# C(county)[T.Queens County]      -0.1963      0.147     -1.338      0.185      -0.488       0.096
# C(county)[T.Richmond County]     0.2161      0.195      1.111      0.270      -0.171       0.603
# logrent                          1.0311      0.159      6.465      0.000       0.714       1.349
# recycling_bin_count             -0.1069      0.044     -2.428      0.017      -0.195      -0.019
# restaurant_count                -0.0001      0.000     -0.281      0.780      -0.001       0.001
# population                   -3.965e-06   2.79e-06     -1.420      0.160   -9.52e-06    1.59e-06
# restaurant_count:population   3.751e-09   1.09e-08      0.345      0.731   -1.79e-08    2.54e-08
# ==============================================================================
# Omnibus:                        4.943   Durbin-Watson:                   1.911
# Prob(Omnibus):                  0.084   Jarque-Bera (JB):                4.914
# Skew:                          -0.564   Prob(JB):                       0.0857
# Kurtosis:                       2.851   Cond. No.                     5.03e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.03e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model7 = smf.ols(formula='logincome ~ logrent + recycling_bin_count*population + C(subway_bracket) + restaurant_count*population + C(county)',
                 data=df).fit()
model7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              logincome   R-squared:                       0.584
# Model:                            OLS   Adj. R-squared:                  0.520
# Method:                 Least Squares   F-statistic:                     9.123
# Date:                Wed, 13 Mar 2019   Prob (F-statistic):           1.13e-10
# Time:                        17:34:52   Log-Likelihood:                -11.319
# No. Observations:                  91   AIC:                             48.64
# Df Residuals:                      78   BIC:                             81.28
# Df Model:                          12
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          3.4313      1.237      2.773      0.007       0.968       5.895
# C(subway_bracket)[T.(6, 72]]       0.0468      0.094      0.500      0.619      -0.140       0.233
# C(subway_bracket)[T.0]             0.1810      0.100      1.802      0.075      -0.019       0.381
# C(county)[T.Kings County]         -0.2279      0.149     -1.534      0.129      -0.524       0.068
# C(county)[T.New York County]      -0.3071      0.153     -2.007      0.048      -0.612      -0.003
# C(county)[T.Queens County]        -0.2053      0.148     -1.390      0.169      -0.499       0.089
# C(county)[T.Richmond County]       0.2244      0.196      1.147      0.255      -0.165       0.614
# logrent                            1.0139      0.162      6.263      0.000       0.692       1.336
# recycling_bin_count               -0.0489      0.094     -0.522      0.603      -0.236       0.138
# population                     -3.103e-06   3.06e-06     -1.014      0.314    -9.2e-06    2.99e-06
# recycling_bin_count:population -1.374e-06   1.96e-06     -0.701      0.486   -5.28e-06    2.53e-06
# restaurant_count                  -0.0002      0.000     -0.383      0.703      -0.001       0.001
# restaurant_count:population     6.178e-09   1.15e-08      0.539      0.591   -1.66e-08     2.9e-08
# ==============================================================================
# Omnibus:                        3.858   Durbin-Watson:                   1.902
# Prob(Omnibus):                  0.145   Jarque-Bera (JB):                3.772
# Skew:                          -0.493   Prob(JB):                        0.152
# Kurtosis:                       2.843   Cond. No.                     5.06e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.06e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model8 = smf.ols(formula='logincome ~ logrent + recycling_bin_count',
                 data=df).fit()
model8.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              logincome   R-squared:                       0.471
# Model:                            OLS   Adj. R-squared:                  0.459
# Method:                 Least Squares   F-statistic:                     39.11
# Date:                Wed, 13 Mar 2019   Prob (F-statistic):           7.04e-13
# Time:                        17:34:52   Log-Likelihood:                -22.285
# No. Observations:                  91   AIC:                             50.57
# Df Residuals:                      88   BIC:                             58.10
# Df Model:                           2
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               3.5251      0.851      4.140      0.000       1.833       5.217
# logrent                 0.9656      0.109      8.822      0.000       0.748       1.183
# recycling_bin_count    -0.0943      0.041     -2.290      0.024      -0.176      -0.012
# ==============================================================================
# Omnibus:                        7.179   Durbin-Watson:                   1.646
# Prob(Omnibus):                  0.028   Jarque-Bera (JB):                7.519
# Skew:                          -0.685   Prob(JB):                       0.0233
# Kurtosis:                       2.674   Cond. No.                         208.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model9 = smf.ols(formula='logincome ~ C(county)*(logrent + recycling_bin_count)',
                 data=df).fit()
model9.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              logincome   R-squared:                       0.598
# Model:                            OLS   Adj. R-squared:                  0.525
# Method:                 Least Squares   F-statistic:                     8.092
# Date:                Wed, 13 Mar 2019   Prob (F-statistic):           3.15e-10
# Time:                        17:34:52   Log-Likelihood:                -9.7014
# No. Observations:                  91   AIC:                             49.40
# Df Residuals:                      76   BIC:                             87.07
# Df Model:                          14
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                           -3.6586      7.097     -0.516      0.608     -17.793      10.476
# C(county)[T.Kings County]                           10.9293      7.914      1.381      0.171      -4.832      26.691
# C(county)[T.New York County]                         4.8239      7.199      0.670      0.505      -9.515      19.163
# C(county)[T.Queens County]                          12.4844      8.071      1.547      0.126      -3.590      28.559
# C(county)[T.Richmond County]                       -28.0181     49.010     -0.572      0.569    -125.629      69.593
# logrent                                              1.9788      0.949      2.086      0.040       0.089       3.868
# C(county)[T.Kings County]:logrent                   -1.5297      1.055     -1.449      0.151      -3.632       0.572
# C(county)[T.New York County]:logrent                -0.7093      0.961     -0.738      0.463      -2.623       1.204
# C(county)[T.Queens County]:logrent                  -1.7073      1.072     -1.592      0.115      -3.843       0.428
# C(county)[T.Richmond County]:logrent                 3.5637      6.356      0.561      0.577      -9.094      16.222
# recycling_bin_count                                 -0.2186      0.177     -1.236      0.220      -0.571       0.134
# C(county)[T.Kings County]:recycling_bin_count        0.2859      0.207      1.379      0.172      -0.127       0.699
# C(county)[T.New York County]:recycling_bin_count     0.0239      0.185      0.129      0.898      -0.345       0.393
# C(county)[T.Queens County]:recycling_bin_count       0.2354      0.207      1.140      0.258      -0.176       0.647
# C(county)[T.Richmond County]:recycling_bin_count     0.2272      0.410      0.554      0.581      -0.589       1.043
# ==============================================================================
# Omnibus:                        4.216   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.121   Jarque-Bera (JB):                3.989
# Skew:                          -0.513   Prob(JB):                        0.136
# Kurtosis:                       2.964   Cond. No.                     1.49e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.49e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df.head()
# Out:
#    Unnamed: 0  zipcode  median_income  population           county  \
# 0           0    10001     71244.6100       17678  New York County
# 1           1    10002     30843.9574       70878  New York County
# 2           2    10003     89998.5339       53609  New York County
# 3           3    10004    110183.6857        1271  New York County
# 4           4    10005    115133.2855        1517  New York County
#
#    median_rent  restaurant_count  recycling_bin_count  num_subway_entrances  \
# 0       3400.0             488.0             0.693147                  51.0
# 1       3050.0             509.0             2.397895                  19.0
# 2       3750.0             682.0             2.079442                  28.0
# 3       3876.0             145.0             1.386294                   6.0
# 4       3910.0              72.0             1.386294                   0.0
#
#   subway_bracket  logincome   logrent  logrestaurant
# 0        (6, 72]  11.173874  8.131531       6.190315
# 1        (6, 72]  10.336696  8.022897       6.232448
# 2        (6, 72]  11.407549  8.229511       6.525030
# 3         (0, 6]  11.609904  8.262559       4.976734
# 4              0  11.653846  8.271293       4.276666

# %% [markdown]
# ## Remove Staten Island

# %%
df2 = df[df.county != "Richmond County"]
df2
df2.to_csv('df_ex-SI.csv')

# %%
model_exp = smf.ols(formula='logincome ~ restaurant_count*population + recycling_bin_count + logrent',
                 data=df2).fit()
model_exp.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              logincome   R-squared:                       0.532
# Model:                            OLS   Adj. R-squared:                  0.503
# Method:                 Least Squares   F-statistic:                     18.43
# Date:                Wed, 13 Mar 2019   Prob (F-statistic):           3.53e-12
# Time:                        17:34:52   Log-Likelihood:                -17.167
# No. Observations:                  87   AIC:                             46.33
# Df Residuals:                      81   BIC:                             61.13
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       4.4535      1.132      3.934      0.000       2.201       6.706
# restaurant_count            -7.957e-05      0.000     -0.176      0.861      -0.001       0.001
# population                  -3.823e-06   2.69e-06     -1.421      0.159   -9.17e-06    1.53e-06
# restaurant_count:population  1.997e-09    1.1e-08      0.181      0.857   -1.99e-08    2.39e-08
# recycling_bin_count            -0.1040      0.042     -2.502      0.014      -0.187      -0.021
# logrent                         0.8681      0.141      6.146      0.000       0.587       1.149
# ==============================================================================
# Omnibus:                        7.480   Durbin-Watson:                   1.684
# Prob(Omnibus):                  0.024   Jarque-Bera (JB):                7.854
# Skew:                          -0.730   Prob(JB):                       0.0197
# Kurtosis:                       2.811   Cond. No.                     4.42e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.42e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# BACK-UP MODEL ('logincome ~ logrent + recycling_bin_count + population')
modela = smf.ols(formula='logincome ~ logrent + recycling_bin_count + population',
                 data=df2).fit()
modela.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              logincome   R-squared:                       0.532
# Model:                            OLS   Adj. R-squared:                  0.515
# Method:                 Least Squares   F-statistic:                     31.45
# Date:                Wed, 13 Mar 2019   Prob (F-statistic):           1.12e-13
# Time:                        17:34:52   Log-Likelihood:                -17.186
# No. Observations:                  87   AIC:                             42.37
# Df Residuals:                      83   BIC:                             52.24
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               4.4310      0.937      4.730      0.000       2.568       6.294
# logrent                 0.8691      0.117      7.454      0.000       0.637       1.101
# recycling_bin_count    -0.1030      0.040     -2.572      0.012      -0.183      -0.023
# population          -3.449e-06   1.42e-06     -2.434      0.017   -6.27e-06    -6.3e-07
# ==============================================================================
# Omnibus:                        7.333   Durbin-Watson:                   1.682
# Prob(Omnibus):                  0.026   Jarque-Bera (JB):                7.699
# Skew:                          -0.720   Prob(JB):                       0.0213
# Kurtosis:                       2.780   Cond. No.                     1.51e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.51e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df2.dtypes
# Out:
# Unnamed: 0                int64
# zipcode                   int64
# median_income           float64
# population                int64
# county                   object
# median_rent             float64
# restaurant_count        float64
# recycling_bin_count     float64
# num_subway_entrances    float64
# subway_bracket           object
# logincome               float64
# logrent                 float64
# logrestaurant           float64
# dtype: object

# %%
df2['predicted_inc'] = 4.3367 + (0.8752*df2['logrent']) - (0.0224*df2['recycling_bin_count']) - (0.000003356*df2['population'])
# Out:
# /Users/gracejeong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2['difference'] = df2['logincome'] - df2['predicted_inc']
# Out:
# /Users/gracejeong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2
# Out:
#     Unnamed: 0  zipcode  median_income  population           county  \
# 0            0    10001     71244.6100       17678  New York County
# 1            1    10002     30843.9574       70878  New York County
# 2            2    10003     89998.5339       53609  New York County
# 3            3    10004    110183.6857        1271  New York County
# 4            4    10005    115133.2855        1517  New York County
# 5            5    10006    111220.0000         972  New York County
# 6            6    10007    145458.7823        3520  New York County
# 7            7    10009     56615.2777       56975  New York County
# 8            8    10010     93702.0061       27322  New York County
# 9            9    10011     92359.4888       45899  New York County
# 10          10    10012     81316.7066       26464  New York County
# 11          11    10013     69836.0955       24723  New York County
# 12          12    10014     98449.9155       32867  New York County
# 13          13    10016     96760.4462       49904  New York County
# 14          14    10017    102523.5025       16231  New York County
# 15          15    10018     84799.0772        4255  New York County
# 16          16    10019     84786.4665       39048  New York County
# 17          17    10021    113800.3846       44173  New York County
# 18          18    10022     93106.6559       26460  New York County
# 19          19    10023    108285.5918       59002  New York County
# 20          20    10024    110998.9883       61485  New York County
# 21          21    10025     65001.2415       96117  New York County
# 22          22    10026     31541.8106       25925  New York County
# 23          23    10027     38550.3989       57049  New York County
# 24          24    10028    105456.4514       40914  New York County
# 25          25    10029     32876.5220       76271  New York County
# 26          26    10030     28525.1218       26058  New York County
# 27          27    10031     31526.0287       59450  New York County
# 28          28    10032     29535.9721       54744  New York County
# 29          29    10033     36462.7783       59049  New York County
# ..         ...      ...            ...         ...              ...
# 61          61    11215     81331.0535       59307     Kings County
# 62          62    11216     37290.3205       55021     Kings County
# 63          63    11217     72610.5963       35641     Kings County
# 64          64    11218     48010.6089       75418     Kings County
# 65          65    11221     34005.1582       75020     Kings County
# 66          66    11222     54366.9033       40003     Kings County
# 67          67    11223     39420.9802       74659     Kings County
# 68          68    11226     38763.3706      106461     Kings County
# 69          69    11228     55200.2725       40169     Kings County
# 70          70    11229     49910.6032       80407     Kings County
# 71          71    11230     47496.1618       88449     Kings County
# 72          72    11231     73074.9877       33174  New York County
# 73          73    11234     67952.9473       81033     Kings County
# 74          74    11235     44729.6710       79197     Kings County
# 75          75    11238     61468.5107       49085     Kings County
# 76          76    11354     50019.4132       54286    Queens County
# 77          77    11355     38623.9557       74434    Queens County
# 78          78    11356     67807.8323       20443    Queens County
# 79          79    11357     74096.6311       39650    Queens County
# 80          80    11358     66312.1712       37044    Queens County
# 81          81    11360     72853.7515       18363    Queens County
# 77        (6, 72]  10.561628  7.600902       5.402677      10.703158
# 78              0  11.124433  7.729735       4.060443      11.033158
# 79              0  11.213125  7.824046       4.343805      11.051240
# 80              0  11.102129  7.696213       5.049856      10.923497
# 81              0  11.196209  7.882315       3.091042      11.149067
# 82              0  11.170199  7.696213       4.890349      10.960756
# 83              0  11.020223  7.824046       3.988984      11.014857
# 84              0  10.888645  7.549609       3.970292      10.766991
# 85        (6, 72]  10.813920  7.522941       4.553877      10.773616
# 86        (6, 72]  11.148306  7.612090       5.342334      10.732351
# 87         (0, 6]  10.767851  7.696213       5.676754      10.737200
# 88        (6, 72]  10.825586  7.783224       5.225747      10.948756
# 89        (6, 72]  10.708216  7.575585       4.709530      10.792529
# 90         (0, 6]  10.912790  7.377759       3.583519      10.756396
#
#     difference
# 0    -0.204687
# 1    -0.730064
# 2     0.094872
# 3     0.077131
# 4     0.114254
# 5     0.119716
# 6    -0.045644
# 7    -0.246092
# 8     0.060782
# 9     0.076770
# 10    0.003688
# 11   -0.533842
# 12    0.140845
# 13    0.218665
# 14    0.273055
# 15   -0.079163
# 16    0.001321
# 17    0.364484
# 18    0.140445
# 19    0.313046
# 20    0.396332
# 21   -0.033159
# 22   -0.728969
# 23   -0.442844
# 24    0.390669
# 25   -0.759424
# 26   -0.514756
# 27   -0.415400
# 28   -0.435980
# 29   -0.264636
# ..         ...
# 61    0.293792
# 62   -0.400190
# 63   -0.019958
# 64    0.000569
# 65   -0.462543
# 66   -0.224863
# 67   -0.118716
# 68    0.084856
# 69   -0.018895
# 70    0.040018
# 71    0.233992
# 72   -0.049648
# 73    0.326092
# 74    0.016221
# 75   -0.079604
# 76   -0.108979
# 77   -0.141530
# 78    0.091275
# 79    0.161886
# 80    0.178632
# 81    0.047142
# 82    0.209443
# 83    0.005367
# 84    0.121654
# 85    0.040304
# 86    0.415954
# 87    0.030651
# 88   -0.123171
# 89   -0.084313
# 90    0.156394
#
# [87 rows x 15 columns]

# %%
df2.to_csv('df_ex-SI.csv')

# %%
# PREDICTION DIFFERENCE OF BACK-UP MODEL
plt.figure(figsize = [12,8])
sns.distplot(df2['difference'])
plt.savefig('model_diff_hist.png')

# %%
# PARTIAL RESIDUAL PLOT FOR BACK-UP MODEL
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_partregress_grid(modela, fig=fig)

# %%
# ANOVA FOR BACKUP MODEL
formula = 'logincome ~ logrent + recycling_bin_count + population'
lm = ols(formula, df2).fit()
table = sm.stats.anova_lm(lm, typ=2)
print(table)
# Out:
#                        sum_sq    df          F        PR(>F)
# logrent              5.061556   1.0  55.556619  7.878006e-11
# recycling_bin_count  0.602508   1.0   6.613249  1.190460e-02
# population           0.539634   1.0   5.923126  1.708947e-02
# Residual             7.561820  83.0        NaN           NaN

# %%
modela.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              logincome   R-squared:                       0.532
# Model:                            OLS   Adj. R-squared:                  0.515
# Method:                 Least Squares   F-statistic:                     31.45
# Date:                Wed, 13 Mar 2019   Prob (F-statistic):           1.12e-13
# Time:                        17:34:53   Log-Likelihood:                -17.186
# No. Observations:                  87   AIC:                             42.37
# Df Residuals:                      83   BIC:                             52.24
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               4.4310      0.937      4.730      0.000       2.568       6.294
# logrent                 0.8691      0.117      7.454      0.000       0.637       1.101
# recycling_bin_count    -0.1030      0.040     -2.572      0.012      -0.183      -0.023
# population          -3.449e-06   1.42e-06     -2.434      0.017   -6.27e-06    -6.3e-07
# ==============================================================================
# Omnibus:                        7.333   Durbin-Watson:                   1.682
# Prob(Omnibus):                  0.026   Jarque-Bera (JB):                7.699
# Skew:                          -0.720   Prob(JB):                       0.0213
# Kurtosis:                       2.780   Cond. No.                     1.51e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.51e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
modelb = smf.ols(formula='logincome ~ logrent + recycling_bin_count + population +C(county)',
                 data=df2).fit()
modelb.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              logincome   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.526
# Method:                 Least Squares   F-statistic:                     16.88
# Date:                Wed, 13 Mar 2019   Prob (F-statistic):           1.72e-12
# Time:                        17:34:53   Log-Likelihood:                -14.630
# No. Observations:                  87   AIC:                             43.26
# Df Residuals:                      80   BIC:                             60.52
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        3.2658      1.079      3.026      0.003       1.118       5.414
# C(county)[T.Kings County]       -0.2303      0.145     -1.593      0.115      -0.518       0.057
# C(county)[T.New York County]    -0.3173      0.151     -2.104      0.039      -0.618      -0.017
# C(county)[T.Queens County]      -0.1836      0.146     -1.259      0.212      -0.474       0.107
# logrent                          1.0519      0.143      7.377      0.000       0.768       1.336
# recycling_bin_count             -0.1214      0.042     -2.911      0.005      -0.204      -0.038
# population                   -3.523e-06   1.55e-06     -2.274      0.026   -6.61e-06    -4.4e-07
# ==============================================================================
# Omnibus:                        5.807   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.055   Jarque-Bera (JB):                5.759
# Skew:                          -0.629   Prob(JB):                       0.0562
# Kurtosis:                       2.927   Cond. No.                     1.76e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.76e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df2_pairplot = df2[['median_income','population', 'median_rent', 'restaurant_count', 'recycling_bin_count', 'num_subway_entrances']]

# %%
sns.heatmap(df2_pairplot.corr(),vmin=-1, vmax=1, annot = True)
plt.savefig('heatmap_exSI.png')

# %%
residual = modela.resid
fig = sm.graphics.qqplot(residual, dist=stats.norm, line='45', fit=True)
fig.show()
# Out:
# /Users/gracejeong/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
df2
# Out:
#     Unnamed: 0  zipcode  median_income  population           county  \
# 0            0    10001     71244.6100       17678  New York County
# 1            1    10002     30843.9574       70878  New York County
# 2            2    10003     89998.5339       53609  New York County
# 3            3    10004    110183.6857        1271  New York County
# 4            4    10005    115133.2855        1517  New York County
# 5            5    10006    111220.0000         972  New York County
# 6            6    10007    145458.7823        3520  New York County
# 7            7    10009     56615.2777       56975  New York County
# 8            8    10010     93702.0061       27322  New York County
# 9            9    10011     92359.4888       45899  New York County
# 10          10    10012     81316.7066       26464  New York County
# 11          11    10013     69836.0955       24723  New York County
# 12          12    10014     98449.9155       32867  New York County
# 13          13    10016     96760.4462       49904  New York County
# 14          14    10017    102523.5025       16231  New York County
# 15          15    10018     84799.0772        4255  New York County
# 16          16    10019     84786.4665       39048  New York County
# 17          17    10021    113800.3846       44173  New York County
# 18          18    10022     93106.6559       26460  New York County
# 19          19    10023    108285.5918       59002  New York County
# 20          20    10024    110998.9883       61485  New York County
# 21          21    10025     65001.2415       96117  New York County
# 22          22    10026     31541.8106       25925  New York County
# 23          23    10027     38550.3989       57049  New York County
# 24          24    10028    105456.4514       40914  New York County
# 25          25    10029     32876.5220       76271  New York County
# 26          26    10030     28525.1218       26058  New York County
# 27          27    10031     31526.0287       59450  New York County
# 28          28    10032     29535.9721       54744  New York County
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20,10))
sns.regplot(x ='logrent', y ='logincome', scatter=True, data = df2, ax = axes[0,0])
sns.regplot(x ='recycling_bin_count', y ='logincome', scatter = True, data = df2, ax = axes[0,1])
sns.regplot(x ='population', y ='logincome', scatter=True, data = df2, ax = axes[1,0])
sns.regplot(x ='logrestaurant', y ='logincome', scatter=True, data = df2, ax = axes[1,1])

# %%
plt.savefig('heteroskedasticity_subplots_backupmodel.png')

# %% [markdown]
# ## Test Model using df-exSI with county dummies

# %%
import pandas as pd

# %%
df_dum = pd.read_csv('df_ex-SI_dummies.csv')
df_dum.head()
# Out:
#    Unnamed: 0  zipcode  median_income  population           county  \
# 0           0    10001     71244.6100       17678  New York County
# 1           1    10002     30843.9574       70878  New York County
# 2           2    10003     89998.5339       53609  New York County
# 3           3    10004    110183.6857        1271  New York County
# 4           4    10005    115133.2855        1517  New York County
#
#    median_rent  restaurant_count  recycling_bin_count  num_subway_entrances  \
# 0       3400.0             488.0                  1.0                  51.0
# 1       3050.0             509.0                 10.0                  19.0
# 2       3750.0             682.0                  7.0                  28.0
# 3       3876.0             145.0                  3.0                   6.0
# 4       3910.0              72.0                  3.0                   0.0
#
#   subway_bracket  logincome   logrent  logrestaurant  predicted_inc  \
# 0        (6, 72]  11.173874  8.131531       6.190315      11.371688
# 1        (6, 72]  10.336696  8.022897       6.232448      10.896473
# 2        (6, 72]  11.407549  8.229511       6.525030      11.202456
# 3         (0, 6]  11.609904  8.262559       4.976734      11.496626
# 4              0  11.653846  8.271293       4.276666      11.503444
#
#    difference  bronx  kings  newyork  queens
# 0   -0.197814      0      0        1       0
# 1   -0.559777      0      0        1       0
# 2    0.205092      0      0        1       0
# 3    0.113278      0      0        1       0
# 4    0.150401      0      0        1       0

# %%
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm
import statsmodels.stats.api as sms
import statsmodels.formula.api as smf
import scipy.stats as stats
import seaborn as sns
from statsmodels.formula.api import ols 

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
df_dum.rename(columns = {'Bronx County': 'bronx', 'Kings County': 'kings', 'Queens County': 'queens', 
                                  'New York County': 'newyork' }, inplace = True)

# %%
df_dum.head()
# Out:
#    Unnamed: 0  zipcode  median_income  population           county  \
# 0           0    10001     71244.6100       17678  New York County
# 1           1    10002     30843.9574       70878  New York County
# 2           2    10003     89998.5339       53609  New York County
# 3           3    10004    110183.6857        1271  New York County
# 4           4    10005    115133.2855        1517  New York County
#
#    median_rent  restaurant_count  recycling_bin_count  num_subway_entrances  \
# 0       3400.0             488.0                  1.0                  51.0
# 1       3050.0             509.0                 10.0                  19.0
# 2       3750.0             682.0                  7.0                  28.0
# 3       3876.0             145.0                  3.0                   6.0
# 4       3910.0              72.0                  3.0                   0.0
#
#   subway_bracket  logincome   logrent  logrestaurant  predicted_inc  \
# 0        (6, 72]  11.173874  8.131531       6.190315      11.371688
# 1        (6, 72]  10.336696  8.022897       6.232448      10.896473
# 2        (6, 72]  11.407549  8.229511       6.525030      11.202456
# 3         (0, 6]  11.609904  8.262559       4.976734      11.496626
# 4              0  11.653846  8.271293       4.276666      11.503444
#
#    difference  bronx  kings  newyork  queens
# 0   -0.197814      0      0        1       0
# 1   -0.559777      0      0        1       0
# 2    0.205092      0      0        1       0
# 3    0.113278      0      0        1       0
# 4    0.150401      0      0        1       0

# %%
model_d1 = smf.ols(formula='logincome ~ bronx*logrent + newyork + queens*logrent + kings*logrent + population',
                 data=df_dum).fit()
model_d1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              logincome   R-squared:                       0.547
# Model:                            OLS   Adj. R-squared:                  0.500
# Method:                 Least Squares   F-statistic:                     11.76
# Date:                Wed, 13 Mar 2019   Prob (F-statistic):           7.86e-11
# Time:                        17:34:54   Log-Likelihood:                -15.787
# No. Observations:                  87   AIC:                             49.57
# Df Residuals:                      78   BIC:                             71.77
# Df Model:                           8
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          3.4906      1.836      1.901      0.061      -0.165       7.146
# bronx             -5.7415      5.920     -0.970      0.335     -17.527       6.044
# logrent            1.0941      0.158      6.911      0.000       0.779       1.409
# bronx:logrent      0.6772      0.995      0.680      0.498      -1.304       2.659
# newyork           -1.0113      2.016     -0.502      0.617      -5.024       3.001
# queens             5.7602      3.573      1.612      0.111      -1.354      12.874
# queens:logrent    -0.8550      0.542     -1.577      0.119      -1.935       0.225
# kings              4.4832      2.723      1.646      0.104      -0.938       9.904
# kings:logrent     -0.6938      0.383     -1.812      0.074      -1.456       0.068
# population     -3.863e-06   1.64e-06     -2.359      0.021   -7.12e-06   -6.02e-07
# ==============================================================================
# Omnibus:                        2.301   Durbin-Watson:                   1.914
# Prob(Omnibus):                  0.316   Jarque-Bera (JB):                1.988
# Skew:                          -0.370   Prob(JB):                        0.370
# Kurtosis:                       3.009   Cond. No.                     5.65e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.24e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# ## Test with Staten Island included

# %%
df3 = pd.read_csv('df_master91.csv')
df3.head()
# Out:
#    Unnamed: 0  zipcode  median_income  population           county  \
# 0           0    10001     71244.6100       17678  New York County
# 1           1    10002     30843.9574       70878  New York County
# 2           2    10003     89998.5339       53609  New York County
# 3           3    10004    110183.6857        1271  New York County
# 4           4    10005    115133.2855        1517  New York County
#
#    median_rent  restaurant_count  recycling_bin_count  num_subway_entrances  \
# 0       3400.0             488.0                  1.0                  51.0
# 1       3050.0             509.0                 10.0                  19.0
# 2       3750.0             682.0                  7.0                  28.0
# 3       3876.0             145.0                  3.0                   6.0
# 4       3910.0              72.0                  3.0                   0.0
#
#   subway_bracket
# 0        (6, 72]
# 1        (6, 72]
# 2        (6, 72]
# 3         (0, 6]
# 4              0

# %%
df3 =df3.iloc[:,1:]
df3.head()
# Out:
#    zipcode  median_income  population           county  median_rent  \
# 0    10001     71244.6100       17678  New York County       3400.0
# 1    10002     30843.9574       70878  New York County       3050.0
# 2    10003     89998.5339       53609  New York County       3750.0
# 3    10004    110183.6857        1271  New York County       3876.0
# 4    10005    115133.2855        1517  New York County       3910.0
#
#    restaurant_count  recycling_bin_count  num_subway_entrances subway_bracket
# 0             488.0                  1.0                  51.0        (6, 72]
# 1             509.0                 10.0                  19.0        (6, 72]
# 2             682.0                  7.0                  28.0        (6, 72]
# 3             145.0                  3.0                   6.0         (0, 6]
# 4              72.0                  3.0                   0.0              0

# %%
cat_county3 = df.county.astype('category')
cat_county3.cat.codes
county_dummies3 = pd.get_dummies(cat_county3, drop_first = True)
df3 = pd.concat([df, county_dummies3], axis=1)
df3.head()
# Out:
#    Unnamed: 0  zipcode  median_income  population           county  \
# 0           0    10001     71244.6100       17678  New York County
# 1           1    10002     30843.9574       70878  New York County
# 2           2    10003     89998.5339       53609  New York County
# 3           3    10004    110183.6857        1271  New York County
# 4           4    10005    115133.2855        1517  New York County
#
#    median_rent  restaurant_count  recycling_bin_count  num_subway_entrances  \
# 0       3400.0             488.0             0.693147                  51.0
# 1       3050.0             509.0             2.397895                  19.0
# 2       3750.0             682.0             2.079442                  28.0
# 3       3876.0             145.0             1.386294                   6.0
# 4       3910.0              72.0             1.386294                   0.0
#
#   subway_bracket  logincome   logrent  logrestaurant  Kings County  \
# 0        (6, 72]  11.173874  8.131531       6.190315             0
# 1        (6, 72]  10.336696  8.022897       6.232448             0
# 2        (6, 72]  11.407549  8.229511       6.525030             0
# 3         (0, 6]  11.609904  8.262559       4.976734             0
# 4              0  11.653846  8.271293       4.276666             0
#
#    New York County  Queens County  Richmond County
# 0                1              0                0
# 1                1              0                0
# 2                1              0                0
# 3                1              0                0
# 4                1              0                0

# %%
df3.rename(columns = {'Richmond County': 'staten', 'Kings County': 'kings', 'Queens County': 'queens', 
                                  'New York County': 'newyork' }, inplace = True)

# %%
df3['sub_dummy'] = np.where(df3['num_subway_entrances']!=0, 1, 0)

# %%
df3.head()
# Out:
#    Unnamed: 0  zipcode  median_income  population           county  \
# 0           0    10001     71244.6100       17678  New York County
# 1           1    10002     30843.9574       70878  New York County
# 2           2    10003     89998.5339       53609  New York County
# 3           3    10004    110183.6857        1271  New York County
# 4           4    10005    115133.2855        1517  New York County
#
#    median_rent  restaurant_count  recycling_bin_count  num_subway_entrances  \
# 0       3400.0             488.0             0.693147                  51.0
# 1       3050.0             509.0             2.397895                  19.0
# 2       3750.0             682.0             2.079442                  28.0
# 3       3876.0             145.0             1.386294                   6.0
# 4       3910.0              72.0             1.386294                   0.0
#
#   subway_bracket  logincome   logrent  logrestaurant  kings  newyork  queens  \
# 0        (6, 72]  11.173874  8.131531       6.190315      0        1       0
# 1        (6, 72]  10.336696  8.022897       6.232448      0        1       0
# 2        (6, 72]  11.407549  8.229511       6.525030      0        1       0
# 3         (0, 6]  11.609904  8.262559       4.976734      0        1       0
# 4              0  11.653846  8.271293       4.276666      0        1       0
#
#    staten  sub_dummy
# 0       0          1
# 1       0          1
# 2       0          1
# 3       0          1
# 4       0          0

# %%
model_d3 = smf.ols(formula='logincome ~ C(county) + logrent + recycling_bin_count + restaurant_count + sub_dummy + population',
                 data=df3).fit()
model_d3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              logincome   R-squared:                       0.580
# Model:                            OLS   Adj. R-squared:                  0.533
# Method:                 Least Squares   F-statistic:                     12.42
# Date:                Wed, 13 Mar 2019   Prob (F-statistic):           3.86e-12
# Time:                        17:34:55   Log-Likelihood:                -11.760
# No. Observations:                  91   AIC:                             43.52
# Df Residuals:                      81   BIC:                             68.63
# Df Model:                           9
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        3.4283      1.182      2.901      0.005       1.077       5.780
# C(county)[T.Kings County]       -0.1984      0.142     -1.394      0.167      -0.482       0.085
# C(county)[T.New York County]    -0.2828      0.148     -1.907      0.060      -0.578       0.012
# C(county)[T.Queens County]      -0.1837      0.143     -1.289      0.201      -0.467       0.100
# C(county)[T.Richmond County]     0.2009      0.190      1.057      0.294      -0.177       0.579
# logrent                          1.0366      0.156      6.659      0.000       0.727       1.346
# recycling_bin_count             -0.1006      0.042     -2.402      0.019      -0.184      -0.017
# restaurant_count              8.414e-06      0.000      0.034      0.973      -0.000       0.001
# sub_dummy                       -0.1502      0.073     -2.044      0.044      -0.296      -0.004
# population                   -3.101e-06    1.6e-06     -1.937      0.056   -6.29e-06     8.5e-08
# ==============================================================================
# Omnibus:                        4.667   Durbin-Watson:                   1.944
# Prob(Omnibus):                  0.097   Jarque-Bera (JB):                4.652
# Skew:                          -0.546   Prob(JB):                       0.0977
# Kurtosis:                       2.816   Cond. No.                     2.03e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.03e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
## FINAL MODEL FOR PRESENTATION
model_fin = ols(formula="logincome~logrent+sub_dummy+population+recycling_bin_count+C(county)",
                               data=df3).fit()
model_fin.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              logincome   R-squared:                       0.580
# Model:                            OLS   Adj. R-squared:                  0.539
# Method:                 Least Squares   F-statistic:                     14.15
# Date:                Wed, 13 Mar 2019   Prob (F-statistic):           9.83e-13
# Time:                        17:34:55   Log-Likelihood:                -11.761
# No. Observations:                  91   AIC:                             41.52
# Df Residuals:                      82   BIC:                             64.12
# Df Model:                           8
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        3.4105      1.051      3.244      0.002       1.319       5.502
# C(county)[T.Kings County]       -0.1985      0.141     -1.404      0.164      -0.480       0.083
# C(county)[T.New York County]    -0.2827      0.147     -1.919      0.058      -0.576       0.010
# C(county)[T.Queens County]      -0.1836      0.142     -1.296      0.198      -0.465       0.098
# C(county)[T.Richmond County]     0.2001      0.188      1.067      0.289      -0.173       0.573
# logrent                          1.0389      0.139      7.494      0.000       0.763       1.315
# sub_dummy                       -0.1501      0.073     -2.057      0.043      -0.295      -0.005
# population                   -3.081e-06   1.48e-06     -2.078      0.041   -6.03e-06   -1.32e-07
# recycling_bin_count             -0.1004      0.041     -2.436      0.017      -0.182      -0.018
# ==============================================================================
# Omnibus:                        4.670   Durbin-Watson:                   1.945
# Prob(Omnibus):                  0.097   Jarque-Bera (JB):                4.654
# Skew:                          -0.546   Prob(JB):                       0.0976
# Kurtosis:                       2.817   Cond. No.                     1.82e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.82e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
residual = model_fin.resid
fig = sm.graphics.qqplot(residual, dist=stats.norm, line='45', fit=True)
fig.show()
# Out:
# /Users/gracejeong/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
df3['diff_act_pred'] = 3.3093 -0.1885df['kings'] -0.2757
# Out:
#   File "<ipython-input-76-ea0ded768968>", line 1
#     df3['diff_act_pred'] = 3.3093 -0.1885df['kings'] -0.2757
#                                           ^
# SyntaxError: invalid syntax
