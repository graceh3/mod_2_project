# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from itertools import combinations
import matplotlib.pyplot as plt


from matplotlib.pyplot import cm

# %%
df = pd.read_csv('df_ex-SI_dummies.csv')

# %%
def category_plot(data, category_column, x_column, y_column):
    plt.figure(figsize=(10,6))
    cat_names=data[category_column].unique()
    n_cats=len(cat_names)
    color=iter(cm.rainbow(np.linspace(0,1,n_cats)))
    for cat in cat_names:        
        c=next(color)
        regression = LinearRegression()
        cat_data = data[data[category_column]==cat]
        cat_x = cat_data[x_column].values.reshape(-1, 1)
        regression.fit(cat_x, cat_data[y_column])
        pred = regression.predict(cat_x)
        plt.scatter(cat_x, cat_data[y_column],  color=c, alpha = 0.3, label = cat)
        plt.plot(cat_x, pred,  color=c, linewidth=2)
    plt.ylabel("")
    plt.xlabel("")
    plt.legend();

# %%
df[df.rest_per_capita > 0.1]
# Out:
#    Unnamed: 0  zipcode  median_income  population           county  \
# 3           3    10004    110183.6857        1271  New York County
#
#    median_rent  restaurant_count  recycling_bin_count  num_subway_entrances  \
# 3       3876.0             145.0                  3.0                   6.0
#
#   subway_bracket    ...      predicted_inc  difference  bronx  kings  newyork  \
# 3         (0, 6]    ...          11.496626    0.113278      0      0        1
#
#    queens  subway_dummy  rest_per_capita  bins_per_capita  predicted
# 3       0             1         0.114083          0.00236  11.363982
#
# [1 rows x 23 columns]

# %%
df['logpop']=np.log(df.population)

# %%
df
# Out:
#     Unnamed: 0  zipcode  median_income  population           county  \
# 0            0    10001     71244.6100       17678  New York County
# 1            1    10002     30843.9574       70878  New York County
# 2            2    10003     89998.5339       53609  New York County
# 3            3    10004    110183.6857        1271  New York County
# 4            4    10005    115133.2855        1517  New York County
# 5            5    10006    111220.0000         972  New York County
# 6            6    10007    145458.7823        3520  New York County
# 7            7    10009     56615.2777       56975  New York County
# 8            8    10010     93702.0061       27322  New York County
# 9            9    10011     92359.4888       45899  New York County
# 10          10    10012     81316.7066       26464  New York County
# 11          11    10013     69836.0955       24723  New York County
# 12          12    10014     98449.9155       32867  New York County
# ...

# %%
df.rename(columns = {'Bronx County': 'bronx', 'Kings County': 'kings', 'Queens County': 'queens', 
                                  'New York County': 'newyork' }, inplace = True)

# %%
df['rest_per_log_capita'] = df['restaurant_count'] / df['logpop']

# %%
df['rest_per_capita'] = df['restaurant_count'] / df['population']

# %%
df['bins_per_capita'] = df['recycling_bin_count'] / df['population']

# %%
df['subway_dummy'] = np.where(df['num_subway_entrances']!=0, 1, 0)

# %%
category_plot(df, 'subway_dummy', 'median_rent', 'median_income')

# %%
category_plot(df[df['county']=="New York County"], 'subway_dummy', 'median_rent', 'median_income')

# %%
category_plot(df, 'subway_dummy', 'logrent', 'logincome')

# %%
category_plot(df, 'county', 'median_rent', 'median_income')

# %%
category_plot(df, 'county', 'recycling_bin_count', 'median_income')

# %%
category_plot(df[df.rest_per_capita < 0.06], 'county', 'rest_per_log_capita', 'median_income')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'zipcode', 'median_income', 'population', 'county',
#        'median_rent', 'restaurant_count', 'recycling_bin_count',
#        'num_subway_entrances', 'subway_bracket', 'logincome', 'logrent',
#        'logrestaurant', 'predicted_inc', 'difference', 'bronx', 'kings',
#        'newyork', 'queens', 'subway_dummy', 'rest_per_capita',
#        'bins_per_capita', 'predicted', 'logpop', 'rest_per_log_capita'],
#       dtype='object')

# %%
model1 = ols(formula="logincome~logrent+subway_dummy+recycling_bin_count+kings+newyork+queens+bronx",
                               data=df).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              logincome   R-squared:                       0.553
# Model:                            OLS   Adj. R-squared:                  0.520
# Method:                 Least Squares   F-statistic:                     16.50
# Date:                Fri, 08 Mar 2019   Prob (F-statistic):           2.81e-12
# Time:                        11:51:16   Log-Likelihood:                -15.185
# No. Observations:                  87   AIC:                             44.37
# Df Residuals:                      80   BIC:                             61.63
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
df['predicted']=1.9026+1.1292*df.logrent-0.1772*df.subway_dummy-0.0242*df.recycling_bin_count+0.3989*df.kings+0.3811*df.newyork+0.4800*df.queens+0.6426*df.bronx

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rms = sqrt(mean_squared_error(df.logincome, df.predicted))

# %%
rms
# Out:
# 0.2881156784866008

# %%
np.e**0.2881156784866008
# Out:
# 1.3339116000740072

# %%
model2 = ols(formula="logincome~logrent+subway_dummy+population+recycling_bin_count+C(county)",
                               data=df).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              logincome   R-squared:                       0.575
# Model:                            OLS   Adj. R-squared:                  0.538
# Method:                 Least Squares   F-statistic:                     15.28
# Date:                Fri, 08 Mar 2019   Prob (F-statistic):           1.77e-12
# Time:                        13:22:34   Log-Likelihood:                -12.971
# No. Observations:                  87   AIC:                             41.94
# Df Residuals:                      79   BIC:                             61.67
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
model3 = ols(formula="logincome~subway_dummy+bronx+queens+kings+newyork+logpop+restaurant_count",
                               data=df).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              logincome   R-squared:                       0.395
# Model:                            OLS   Adj. R-squared:                  0.350
# Method:                 Least Squares   F-statistic:                     8.714
# Date:                Fri, 08 Mar 2019   Prob (F-statistic):           2.66e-07
# Time:                        12:05:04   Log-Likelihood:                -28.338
# No. Observations:                  87   AIC:                             70.68
# Df Residuals:                      80   BIC:                             87.94
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
model4 = ols(formula="logincome~logrent+subway_dummy+recycling_bin_count+kings+newyork+queens+bronx",
                               data=df).fit()
model4.summary()
