# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("master_report_streeteasy/rentals/All/rentalInventory_All.csv")

# %%
df.head()
# Out:
#               areaName    Borough   areaType  2010-01  2010-02  2010-03  \
# 0         All Downtown  Manhattan  submarket     4240     4490     4564
# 1          All Midtown  Manhattan  submarket     3118     3269     3289
# 2  All Upper East Side  Manhattan  submarket     2553     2655     2644
# 3  All Upper Manhattan  Manhattan  submarket      846      843      813
# 4  All Upper West Side  Manhattan  submarket     2165     2188     2308
#
#    2010-04  2010-05  2010-06  2010-07   ...     2018-01  2018-02  2018-03  \
# 0     4668     4479     4574     4255   ...        5845     5538     6029
# 1     3452     3161     3148     3066   ...        4178     4061     4351
# 2     2592     2502     2673     2585   ...        2764     2694     2873
# 3      738      707      770      754   ...        2200     2232     2447
# 4     2454     2328     2414     2220   ...        2542     2425     2552
#
#    2018-04  2018-05  2018-06  2018-07  2018-08  2018-09  2018-10
# ...

# %%
dfsum = (df[df.Borough == "Manhattan"].sum())
dfsum[3:].sum()
# Out:
# 5541697

# %%
df_man_multi_counts = df[df.Borough == 'Manhattan'].set_index(["Borough", "areaName"]).sort_index()

# %%
df_man_multi_counts
# Out:
#                                    areaType  2010-01  2010-02  2010-03  \
# Borough   areaName
# Manhattan All Downtown            submarket     4240     4490     4564
#           All Midtown             submarket     3118     3269     3289
#           All Upper East Side     submarket     2553     2655     2644
#           All Upper Manhattan     submarket      846      843      813
#           All Upper West Side     submarket     2165     2188     2308
#           Battery Park City    neighborhood      213      207      206
#           Central Harlem       neighborhood      413      388      333
#           Central Park South   neighborhood      117      105      113
#           Chelsea              neighborhood      605      658      678
#           Chinatown            neighborhood       19       17       16
#           Civic Center         neighborhood        0        0        0
#           East Harlem          neighborhood      131      122      134
# ...

# %%
df_man_multi_counts.describe()
# Out:
#             2010-01       2010-02       2010-03       2010-04       2010-05  \
# count     39.000000     39.000000     39.000000     39.000000     39.000000
# mean     995.538462   1036.230769   1049.897436   1071.692308   1015.205128
# std     2207.252053   2300.227843   2332.242910   2383.626319   2258.000049
# min        0.000000      0.000000      0.000000      0.000000      1.000000
# 25%       82.500000     92.000000     85.500000     80.000000     77.500000
# 50%      239.000000    247.000000    262.000000    276.000000    254.000000
# 75%      709.000000    747.500000    745.500000    702.000000    653.000000
# max    12952.000000  13484.000000  13664.000000  13946.000000  13208.000000
#
#             2010-06       2010-07       2010-08       2010-09       2010-10  \
# count     39.000000     39.000000     39.000000     39.000000     39.000000
# mean    1046.538462    993.897436    938.205128    824.743590    810.410256
# ...
