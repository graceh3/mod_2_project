# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("master_report_streeteasy/rentals/All/discountShare_All.csv")

# %%
df
# Out:
#                 areaName        Borough      areaType   2010-01   2010-02  \
# 0           All Downtown      Manhattan     submarket  0.114387  0.092650
# 1            All Midtown      Manhattan     submarket  0.104554  0.084124
# 2    All Upper East Side      Manhattan     submarket  0.132002  0.109228
# 3    All Upper Manhattan      Manhattan     submarket  0.083924  0.092527
# 4    All Upper West Side      Manhattan     submarket  0.096536  0.110146
# 5             Alley Park         Queens  neighborhood       NaN       NaN
# 6                Astoria         Queens  neighborhood  0.039216  0.020000
# 7             Auburndale         Queens  neighborhood       NaN       NaN
# 8             Bath Beach       Brooklyn  neighborhood       NaN       NaN
# 9      Battery Park City      Manhattan  neighborhood  0.112676  0.057971
# 10             Bay Ridge       Brooklyn  neighborhood  0.020833  0.041667
# 11            Baychester          Bronx  neighborhood       NaN       NaN
# ...
